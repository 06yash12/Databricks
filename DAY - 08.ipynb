# %%
# %sql
CREATE CATALOG ecommerce;
USE CATALOG ecommerce;
CREATE SCHEMA bronze;
CREATE SCHEMA silver;
CREATE SCHEMA gold;

# %%
# %sql
CREATE TABLE ecommerce.bronze.events USING DELTA;
CREATE TABLE ecommerce.silver.events USING DELTA;
CREATE TABLE ecommerce.gold.products USING DELTA;

# %%
# %sql
GRANT SELECT ON TABLE gold.products TO `1207yash@gmail.com`;
GRANT ALL PRIVILEGES ON SCHEMA silver TO `1207yash@gmail.com`;

# %%
# %sql
CREATE VIEW ecommerce.gold.top_products AS
SELECT product_id, revenue, conversion_rate
FROM ecommerce.gold.products
WHERE purchases > 10
ORDER BY revenue DESC LIMIT 100;

# %%
# %sql
SELECT * FROM ecommerce.gold.top_products;

# %%
# %sql
INSERT INTO ecommerce.gold.products
  SELECT * FROM workspace.default.gold_product_performance;
